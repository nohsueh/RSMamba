# %%
! python tools/train.py configs/rsmamba/rsmamba_uc_b.py  # name_to_config.py 为你想要使用的配置文件
# Out:
# ^C
# The fast path is not available because on of `(selective_state_update, selective_scan_fn, causal_conv1d_fn, causal_conv1d_update, mamba_inner_fn)` is None. Falling back to the naive implementation. To install follow https://github.com/state-spaces/mamba/#installation and https://github.com/Dao-AILab/causal-conv1d
# Traceback (most recent call last):
#   File "c:\Users\33859\OneDrive\Projects\RSMamba\tools\train.py", line 164, in <module>
#     main()
#   File "c:\Users\33859\OneDrive\Projects\RSMamba\tools\train.py", line 160, in main
#     runner.train()
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\runner\runner.py", line 1777, in train
#     model = self.train_loop.run()  # type: ignore
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\runner\loops.py", line 96, in run
#     self.run_epoch()
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\runner\loops.py", line 111, in run_epoch
#     for idx, data_batch in enumerate(self.dataloader):
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\_utils.py", line 694, in reraise
#     raise exception
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\_utils\worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\dataset\base_dataset.py", line 410, in __getitem__
#     data = self.prepare_data(idx)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\OneDrive\Projects\RSMamba\tools/..\mmpretrain\rsmamba\datasets\datasets.py", line 41, in prepare_data
#     results = self.pipeline(data_info)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\dataset\base_dataset.py", line 60, in __call__
#     data = t(data)
#            ^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmcv\transforms\base.py", line 12, in __call__
#     return self.transform(results)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmcv\transforms\loading.py", line 107, in transform
#     raise e
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmcv\transforms\loading.py", line 99, in transform
#     img_bytes = fileio.get(
#                 ^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\fileio\io.py", line 181, in get
#     return backend.get(filepath)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\33859\anaconda3\envs\rsmamba\Lib\site-packages\mmengine\fileio\backends\local_backend.py", line 33, in get
#     with open(filepath, 'rb') as f:
#          ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\33859\\Documents\\data\\UCMerced_LandUse/overpass/overpass84.tif'
# 04/22 22:04:11 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1246954546
#     GPU 0: NVIDIA GeForce RTX 4060 Laptop GPU
#     CUDA_HOME: None
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.38.33134 for x64
#     GCC: n/a
#     PyTorch: 2.1.2
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.8.1  (built against CUDA 12.0)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.8.1, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /bigobj /FS -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /utf-8 /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=OFF, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2
#     OpenCV: 4.9.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1246954546
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/22 22:04:11 - mmengine - INFO - Config:
# batch_size = 16
# bgr_mean = [
#     115.35737613,
#     125.41281689,
#     123.770241,
# ]
# bgr_std = [
#     39.5737929,
#     41.63589266,
#     44.17314347,
# ]
# code_root = 'C:\\Users\\33859\\OneDrive\\Projects\\RSMamba\\datainfo\\UC'
# custom_imports = dict(allow_failed_imports=False, imports='mmpretrain.rsmamba')
# data_preprocessor = dict(
#     mean=[
#         123.770241,
#         125.41281689,
#         115.35737613,
#     ],
#     num_classes=21,
#     std=[
#         44.17314347,
#         41.63589266,
#         39.5737929,
#     ],
#     to_rgb=True)
# data_root = 'C:\\Users\\33859\\Documents\\data\\UCMerced_LandUse'
# dataset_type = 'RSClsDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=True,
#         interval=5,
#         max_keep_ckpts=5,
#         rule='greater',
#         save_best='single-label/f1-score',
#         save_last=True,
#         type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         arch='b',
#         cls_position='none',
#         drop_rate=0.0,
#         img_size=224,
#         init_cfg=[
#             dict(
#                 layer='Conv2d',
#                 mode='fan_in',
#                 nonlinearity='linear',
#                 type='Kaiming'),
#         ],
#         out_type='avg_featmap',
#         patch_cfg=dict(stride=8),
#         patch_size=16,
#         path_type='forward_reverse_shuffle_gate',
#         pe_type='learnable',
#         type='RSMamba'),
#     head=dict(
#         in_channels=192,
#         init_cfg=None,
#         loss=dict(
#             label_smooth_val=0.1, mode='original', type='LabelSmoothLoss'),
#         num_classes=21,
#         type='LinearClsHead'),
#     neck=None,
#     train_cfg=dict(augments=[
#         dict(alpha=0.8, type='Mixup'),
#         dict(alpha=1.0, type='CutMix'),
#     ]),
#     type='ImageClassifier')
# num_classes = 21
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0005, type='AdamW', weight_decay=0.05))
# param_scheduler = [
#     dict(
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=10,
#         start_factor=0.001,
#         type='LinearLR'),
#     dict(begin=10, by_epoch=True, eta_min=1e-05, type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=16,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file=
#         'C:\\Users\\33859\\OneDrive\\Projects\\RSMamba\\datainfo\\UC/val.txt',
#         data_name='UC',
#         data_root='C:\\Users\\33859\\Documents\\data\\UCMerced_LandUse',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 edge='short',
#                 interpolation='bicubic',
#                 scale=256,
#                 type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(num_classes=21, type='SingleLabelMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         backend='pillow',
#         edge='short',
#         interpolation='bicubic',
#         scale=256,
#         type='ResizeEdge'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(by_epoch=True, max_epochs=500, val_interval=20)
# train_dataloader = dict(
#     batch_size=16,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file=
#         'C:\\Users\\33859\\OneDrive\\Projects\\RSMamba\\datainfo\\UC/train.txt',
#         data_name='UC',
#         data_root='C:\\Users\\33859\\Documents\\data\\UCMerced_LandUse',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 crop_ratio_range=(
#                     0.1,
#                     1.3,
#                 ),
#                 interpolation='bicubic',
#                 scale=224,
#                 type='RandomResizedCrop'),
#             dict(
#                 direction=[
#                     'horizontal',
#                     'vertical',
#                 ],
#                 prob=[
#                     0.5,
#                     0.5,
#                 ],
#                 type='RandomFlip'),
#             dict(
#                 hparams=dict(
#                     interpolation='bicubic', pad_val=[
#                         115,
#                         125,
#                         124,
#                     ]),
#                 policies='imagenet',
#                 type='AutoAugment'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         backend='pillow',
#         crop_ratio_range=(
#             0.1,
#             1.3,
#         ),
#         interpolation='bicubic',
#         scale=224,
#         type='RandomResizedCrop'),
#     dict(
#         direction=[
#             'horizontal',
#             'vertical',
#         ],
#         prob=[
#             0.5,
#             0.5,
#         ],
#         type='RandomFlip'),
#     dict(
#         hparams=dict(interpolation='bicubic', pad_val=[
#             115,
#             125,
#             124,
#         ]),
#         policies='imagenet',
#         type='AutoAugment'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=16,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file=
#         'C:\\Users\\33859\\OneDrive\\Projects\\RSMamba\\datainfo\\UC/val.txt',
#         data_name='UC',
#         data_root='C:\\Users\\33859\\Documents\\data\\UCMerced_LandUse',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 edge='short',
#                 interpolation='bicubic',
#                 scale=256,
#                 type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(num_classes=21, type='SingleLabelMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# warmup_epochs = 10
# work_dir = 'work_dirs/rsmamba_uc_b'
#
# 04/22 22:04:12 - mmengine - INFO - Because batch augmentations are enabled, the data preprocessor automatically enables the `to_onehot` option to generate one-hot format labels.
# 04/22 22:04:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/22 22:04:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 04/22 22:04:13 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 04/22 22:04:13 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 04/22 22:04:13 - mmengine - INFO - Checkpoints will be saved to c:\Users\33859\OneDrive\Projects\RSMamba\work_dirs\rsmamba_uc_b.

# %%
! python tools/test.py configs/rsmamba/rsmamba_nwpu_b.py /root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth  # name_to_config.py 为你想要使用的配置文件，CHECKPOINT_FILE 为你想要使用的检查点文件
# Out:
# 04/22 20:55:34 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 2011615119
#     GPU 0: NVIDIA A10
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2
#     OpenCV: 4.9.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2011615119
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/22 20:55:34 - mmengine - INFO - Config:
# batch_size = 32
# bgr_mean = [
#     87.66547902,
#     97.20128819,
#     93.847266,
# ]
# bgr_std = [
#     33.70191772,
#     34.61650149,
#     37.10216765,
# ]
# code_root = '/root/repo/RSMamba/datainfo/NWPU'
# custom_imports = dict(allow_failed_imports=False, imports='mmpretrain.rsmamba')
# data_preprocessor = dict(
#     mean=[
#         93.847266,
#         97.20128819,
#         87.66547902,
#     ],
#     num_classes=45,
#     std=[
#         37.10216765,
#         34.61650149,
#         33.70191772,
#     ],
#     to_rgb=True)
# data_root = '/root/data/NWPU-RESISC45'
# dataset_type = 'RSClsDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=True,
#         interval=5,
#         max_keep_ckpts=5,
#         rule='greater',
#         save_best='single-label/f1-score',
#         save_last=True,
#         type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = '/root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth'
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         arch='b',
#         cls_position='none',
#         drop_rate=0.0,
#         img_size=224,
#         init_cfg=[
#             dict(
#                 layer='Conv2d',
#                 mode='fan_in',
#                 nonlinearity='linear',
#                 type='Kaiming'),
#         ],
#         out_type='avg_featmap',
#         patch_cfg=dict(stride=8),
#         patch_size=16,
#         path_type='forward_reverse_shuffle_gate',
#         pe_type='learnable',
#         type='RSMamba'),
#     head=dict(
#         in_channels=192,
#         init_cfg=None,
#         loss=dict(
#             label_smooth_val=0.1, mode='original', type='LabelSmoothLoss'),
#         num_classes=45,
#         type='LinearClsHead'),
#     neck=None,
#     train_cfg=dict(augments=[
#         dict(alpha=0.8, type='Mixup'),
#         dict(alpha=1.0, type='CutMix'),
#     ]),
#     type='ImageClassifier')
# num_classes = 45
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0005, type='AdamW', weight_decay=0.05))
# param_scheduler = [
#     dict(
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=10,
#         start_factor=0.001,
#         type='LinearLR'),
#     dict(begin=10, by_epoch=True, eta_min=1e-05, type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='/root/repo/RSMamba/datainfo/NWPU/val.txt',
#         data_name='NWPU',
#         data_root='/root/data/NWPU-RESISC45',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 edge='short',
#                 interpolation='bicubic',
#                 scale=256,
#                 type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(num_classes=30, type='SingleLabelMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         backend='pillow',
#         edge='short',
#         interpolation='bicubic',
#         scale=256,
#         type='ResizeEdge'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(by_epoch=True, max_epochs=11, val_interval=1)
# train_dataloader = dict(
#     batch_size=32,
#     dataset=dict(
#         ann_file='/root/repo/RSMamba/datainfo/NWPU/train.txt',
#         data_name='NWPU',
#         data_root='/root/data/NWPU-RESISC45',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 crop_ratio_range=(
#                     0.1,
#                     1.3,
#                 ),
#                 interpolation='bicubic',
#                 scale=224,
#                 type='RandomResizedCrop'),
#             dict(
#                 direction=[
#                     'horizontal',
#                     'vertical',
#                 ],
#                 prob=[
#                     0.5,
#                     0.5,
#                 ],
#                 type='RandomFlip'),
#             dict(
#                 hparams=dict(interpolation='bicubic', pad_val=[
#                     88,
#                     97,
#                     94,
#                 ]),
#                 policies='imagenet',
#                 type='AutoAugment'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         backend='pillow',
#         crop_ratio_range=(
#             0.1,
#             1.3,
#         ),
#         interpolation='bicubic',
#         scale=224,
#         type='RandomResizedCrop'),
#     dict(
#         direction=[
#             'horizontal',
#             'vertical',
#         ],
#         prob=[
#             0.5,
#             0.5,
#         ],
#         type='RandomFlip'),
#     dict(
#         hparams=dict(interpolation='bicubic', pad_val=[
#             88,
#             97,
#             94,
#         ]),
#         policies='imagenet',
#         type='AutoAugment'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=32,
#     dataset=dict(
#         ann_file='/root/repo/RSMamba/datainfo/NWPU/val.txt',
#         data_name='NWPU',
#         data_root='/root/data/NWPU-RESISC45',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 backend='pillow',
#                 edge='short',
#                 interpolation='bicubic',
#                 scale=256,
#                 type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='RSClsDataset'),
#     num_workers=8,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(num_classes=30, type='SingleLabelMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# warmup_epochs = 10
# work_dir = 'work_dirs/rsmamba_nwpu_b'
#
# 04/22 20:55:34 - mmengine - INFO - Because batch augmentations are enabled, the data preprocessor automatically enables the `to_onehot` option to generate one-hot format labels.
# 04/22 20:55:34 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/22 20:55:34 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: /root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth
# 04/22 20:55:35 - mmengine - INFO - Load checkpoint from /root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth
# 04/22 20:55:37 - mmengine - INFO - Epoch(test) [  5/297]    eta: 0:02:31  time: 0.5187  data_time: 0.0476  memory: 1125
# 04/22 20:55:39 - mmengine - INFO - Epoch(test) [ 10/297]    eta: 0:02:03  time: 0.4287  data_time: 0.0241  memory: 1125
# 04/22 20:55:41 - mmengine - INFO - Epoch(test) [ 15/297]    eta: 0:01:52  time: 0.3394  data_time: 0.0006  memory: 1125
# 04/22 20:55:42 - mmengine - INFO - Epoch(test) [ 20/297]    eta: 0:01:46  time: 0.3399  data_time: 0.0005  memory: 1125
# 04/22 20:56:55 - mmengine - INFO - Epoch(test) [230/297]    eta: 0:00:23  time: 0.3521  data_time: 0.0004  memory: 1125
# 04/22 20:56:57 - mmengine - INFO - Epoch(test) [235/297]    eta: 0:00:21  time: 0.3522  data_time: 0.0004  memory: 1125
# 04/22 20:56:59 - mmengine - INFO - Epoch(test) [240/297]    eta: 0:00:20  time: 0.3521  data_time: 0.0004  memory: 1125
# 04/22 20:57:01 - mmengine - INFO - Epoch(test) [245/297]    eta: 0:00:18  time: 0.3528  data_time: 0.0004  memory: 1125
# 04/22 20:57:03 - mmengine - INFO - Epoch(test) [250/297]    eta: 0:00:16  time: 0.3531  data_time: 0.0004  memory: 1125
# 04/22 20:57:04 - mmengine - INFO - Epoch(test) [255/297]    eta: 0:00:14  time: 0.3534  data_time: 0.0004  memory: 1125
# 04/22 20:57:06 - mmengine - INFO - Epoch(test) [260/297]    eta: 0:00:12  time: 0.3536  data_time: 0.0004  memory: 1125
# 04/22 20:57:08 - mmengine - INFO - Epoch(test) [265/297]    eta: 0:00:11  time: 0.3532  data_time: 0.0004  memory: 1125
# 04/22 20:57:10 - mmengine - INFO - Epoch(test) [270/297]    eta: 0:00:09  time: 0.3536  data_time: 0.0004  memory: 1125
# 04/22 20:57:11 - mmengine - INFO - Epoch(test) [275/297]    eta: 0:00:07  time: 0.3539  data_time: 0.0004  memory: 1125
# 04/22 20:57:13 - mmengine - INFO - Epoch(test) [280/297]    eta: 0:00:05  time: 0.3539  data_time: 0.0004  memory: 1125
# 04/22 20:57:15 - mmengine - INFO - Epoch(test) [285/297]    eta: 0:00:04  time: 0.3539  data_time: 0.0004  memory: 1125
# 04/22 20:57:17 - mmengine - INFO - Epoch(test) [290/297]    eta: 0:00:02  time: 0.3541  data_time: 0.0003  memory: 1125
# 04/22 20:57:18 - mmengine - INFO - Epoch(test) [295/297]    eta: 0:00:00  time: 0.3543  data_time: 0.0003  memory: 1125
# 04/22 20:57:19 - mmengine - INFO - Epoch(test) [297/297]    single-label/precision: 65.0326  single-label/recall: 60.9268  single-label/f1-score: 59.6395  data_time: 0.0012  time: 0.3512

# %%
! python demo/image_demo.py /root/data/AID/Airport/airport_23.jpg  configs/rsmamba/rsmamba_nwpu_b.py --checkpoint /root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth --show-dir /root/repo/RSMamba/output_dir  # IMAGE_FILE 为你想要预测的图像文件，name_to_config.py 为你想要使用的配置文件，CHECKPOINT_FILE 为你想要使用的检查点文件，OUTPUT_DIR 为预测结果的输出路径
# Out:
# 04/22 20:52:29 - mmengine - INFO - Because batch augmentations are enabled, the data preprocessor automatically enables the `to_onehot` option to generate one-hot format labels.
# Loads checkpoint by local backend from path: /root/repo/RSMamba/work_dirs/rsmamba_nwpu_b/epoch_11.pth
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:000m
# {
#   "pred_label": 5,
#   "pred_score": 0.10049085319042206,
#   "pred_class": "thermal_power_station"
# }
